# %% [markdown]
# <a href="https://colab.research.google.com/github/orlandostumpf/Projeto-Imers-o-Alura/blob/main/Busca_docs_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

import pandas as pd
import numpy as np
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
text = 'Hello World'
result = genai.embed_content(model="models/embedding-001", content=text)
print(result['embedding'])
# Out:
# [0.046566796, -0.037675645, -0.027483625, -0.025192047, 0.023942288, -0.0026659463, 0.033149768, -0.011679272, 0.015756048, 0.01123199, 0.046426386, 0.052512858, -0.016256839, -0.07075573, 0.0070364047, -0.01692846, 0.012160805, -0.014925224, 0.004741532, -0.0061813244, 0.007728799, 0.0076145222, -0.027439272, -0.027118564, 0.009740605, 0.011229627, 0.0058514746, -0.07603289, 0.0037761237, 0.068422936, -0.042938843, 0.011240764, -0.06690559, 0.016373722, 0.047134735, -0.052542906, 0.03338529, 0.022396458, -0.0066276244, -0.0022224153, 0.006207036, -0.08901162, -0.03087202, -0.036972243, 0.050054453, -0.0060172463, 0.008251925, -0.0083412295, 0.023283549, -0.089357406, 0.047525145, 0.022444481, 0.043707557, -0.022486746, 0.016384136, -0.016212998, 0.06940867, 0.010211101, -0.073932774, -0.003212413, 0.016919063, 0.01806236, -0.0071006627, 0.06087064, -0.0016640569, -0.016794063, -0.071873076, 0.051156506, 0.043242697, -0.022834944, 0.008551773, -0.036529887, 0.039639305, -0.037539832,
# ...

# %%
print(len(result['embedding']))
# Out:
# 768

# %%
text_2 = 'Ouviram do Ipiranga às margens plácidas'
result_2 = genai.embed_content(model="models/embedding-001", content=text_2)
print(result_2['embedding'])
# Out:
# [-0.012245428, -0.035780374, -0.027125703, 0.007335137, 0.027935268, 0.0136397295, -0.028824184, -0.007095018, -0.015715698, 0.047087695, -0.0052227317, -0.0034443275, -0.018728444, -0.030815363, 0.001186127, 0.0051808045, 0.007884512, -0.020471, -0.021194281, -0.055439424, -0.056189857, 0.04236287, -0.004554168, 0.019891404, 0.004650219, -0.0006349651, -0.039316062, -0.06005321, -0.040354732, 0.028128883, -0.047745366, 0.060423538, -0.029895004, -0.03107429, -0.018408353, -0.01595546, -0.0019367348, 0.033508766, 0.031350065, 0.023231875, 0.034062244, -0.033264767, -0.01643635, -0.01844493, -0.0002027062, -0.051225863, -0.0012295888, 0.045055866, 0.0013359643, -0.05707903, 0.014246859, -0.044478714, 0.026115676, -0.013777286, 0.0013482234, -0.04845339, 0.04776185, 0.021493955, -0.042899724, -0.003895012, -0.033992454, 0.030675218, 0.020210475, 0.04363333, 0.007900102, -0.04577761, 0.020058157, -0.037486523, 0.00022998963, 0.01670159, 0.04636272, -0.10198134, 0.016643489, 0.0006178507
# ...

# %%
print(len(result_2['embedding']))
# Out:
# 768

# %%
title = "A PRÓXIMA GERAÇÃO DE IA PARA DESENVOLVEDORES"
sample_text = ('A próxima geração de IS para desenvolvedores Google e Workspace')
"\n"
"Artigo completo:\n"
"\n"
"Gemini API & Google AI Studio: Uma maneira acessível de explorar e criar protótipos com aplicações de IA generativa"
embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")
print(embeddings)
# Out:
# {'embedding': [0.055166114, 0.018137375, -0.044994656, -0.020246895, 0.0918852, 0.0038863255, -0.014148124, -0.020580698, 0.021249514, 0.06999226, 0.02133255, 0.032796632, -0.029049933, -0.010309216, 0.038622618, -0.0275934, 0.02813322, -0.033842094, -0.0055929986, -0.02384326, 0.009643359, -0.0016985902, -0.0051174792, -0.024646202, -0.02267076, 0.006364597, -0.020990642, -0.06351574, -0.0057487455, 0.02245891, -0.03366618, 0.0268514, -0.04533804, 0.025776496, -0.055111174, 0.0118230255, -0.046966616, -0.018691253, 0.0022151128, -0.00792648, -0.024056775, -0.0772854, -0.0042031654, 0.038271505, 0.023339717, -0.02100693, 0.03153965, 0.024096282, 0.04021029, -0.048771143, 0.007896693, 0.024981327, 0.075208165, -0.020571548, -0.0019786744, -0.020171057, -0.00986217, -0.03494035, 0.015830165, -0.02024281, -0.00584782, 0.021631867, -0.028696822, 0.034888804, -0.0045102052, -0.04717763, -0.02479268, 0.0035760931, 0.012643244, 0.063760586, 0.014982632, 0.0014940535, 0.060244936, -0.0519598
# ...

# %%
DOCUMENT1 = {
    "Título": "Operação do Sistema de controle climático",
    "Conteúdo": "O Googlecar tem um Sistema de controle climático que permite ajustar a temperatura e o fluxo de ar no carro"},
DOCUMENT2 = {
    "Título": "Touchscreen",
    "Conteúdo": "O seu Googlecar tem uma grande tela sensível ao toque que fornece acesso a uma grande variedade de recursos"},
DOCUMENT3 = {
    "Título": "Mudança de marchas",
    "Conteúdo": "Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio"}
documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
import pandas as pd
df = pd.DataFrame(documents)
df
# Out:
#                                                    0         1
# 0  {'Título': 'Operação do Sistema de controle cl...      None
# 1  {'Título': 'Touchscreen', 'Conteúdo': 'O seu G...      None
# 2                                             Título  Conteúdo

# %%
model = 'models/embedding-001'

def embed_fn(title, text):
return genai.embed_content(model=model,
                           content=text,
                           title=title,
                           task_type="RETRIEVAL_DOCUMENT")["embedding"]
# Out:
#   File "<ipython-input-42-f75ae46c22c9>", line 4
#     return genai.embed_content(model=model,
#     ^
# IndentationError: expected an indented block after function definition on line 3
